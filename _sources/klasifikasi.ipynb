# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing

# %%
# Importing the dataset
dataset = "https://raw.githubusercontent.com/FajarAndrianto037/data/main/credit_score.csv"
data = pd.read_csv(dataset)

# %%
data.head()
dataAsli = data.drop(columns=['kpr_aktif', 'rata_rata_overdue'])

# %%
data2 = data[["kpr_aktif"]]

# %%
data2.head(25)
# Out:
#    kpr_aktif
# 0         YA
# 1         YA
# 2      TIDAK
# 3         YA
# 4      TIDAK
# 5      TIDAK
# 6      TIDAK
# 7      TIDAK
# 8      TIDAK
# 9      TIDAK
# 10     TIDAK
# 11     TIDAK
# 12     TIDAK
# 13     TIDAK
# 14     TIDAK
# 15     TIDAK
# 16        YA
# 17     TIDAK
# 18     TIDAK
# 19     TIDAK
# 20     TIDAK
# 21     TIDAK
# 22     TIDAK
# 23     TIDAK
# 24     TIDAK

# %%
aktif = pd.get_dummies(data2)

# %%
data3 = data[["rata_rata_overdue"]]

# %%
data3.head(25)
# Out:
#    rata_rata_overdue
# 0       61 - 90 days
# 1       61 - 90 days
# 2        0 - 30 days
# 3       46 - 60 days
# 4       31 - 45 days
# 5        0 - 30 days
# 6       31 - 45 days
# 7       31 - 45 days
# 8       31 - 45 days
# 9       31 - 45 days
# 10      31 - 45 days
# 11      31 - 45 days
# 12      31 - 45 days
# 13      31 - 45 days
# 14      31 - 45 days
# 15      31 - 45 days
# 16       0 - 30 days
# 17       0 - 30 days
# 18       0 - 30 days
# 19      31 - 45 days
# 20      31 - 45 days
# 21      31 - 45 days
# 22       0 - 30 days
# 23       0 - 30 days
# 24       0 - 30 days

# %%
rata = pd.get_dummies(data3)

# %%
rata
# Out:
#      rata_rata_overdue_0 - 30 days  rata_rata_overdue_31 - 45 days  \
# 0                                0                               0
# 1                                0                               0
# 2                                1                               0
# 3                                0                               0
# 4                                0                               1
# ..                             ...                             ...
# 895                              0                               0
# 896                              0                               0
# 897                              1                               0
# 898                              0                               1
# 899                              1                               0
#
#      rata_rata_overdue_46 - 60 days  rata_rata_overdue_61 - 90 days  \
# 0                                 0                               1
# ...

# %%
dataOlah = pd.concat([aktif, rata], axis=1)

# %%
dataHasil = pd.concat([dataAsli, dataOlah], axis=1)

# %%
dataHasil
# Out:
#      Unnamed: 0 kode_kontrak  pendapatan_setahun_juta  durasi_pinjaman_bulan  \
# 0             1   AGR-000001                      295                     48
# 1             2   AGR-000011                      271                     36
# 2             3   AGR-000030                      159                     12
# 3             4   AGR-000043                      210                     12
# 4             5   AGR-000049                      165                     36
# ..          ...          ...                      ...                    ...
# 895         896   AGR-010739                      112                     48
# 896         897   AGR-010744                      120                     48
# 897         898   AGR-010758                      166                     24
# 898         899   AGR-010775                      196                     48
# 899         900   AGR-010790                      204                     24
#
# ...
